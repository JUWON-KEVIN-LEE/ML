# %%
import tensorflow as tf

# %%
x_data = [1, 2, 3]
y_data = [1, 2, 3]

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0))

# %%
# name : 값의 변화를 추적하거나 살펴보기 쉽게 하기 위해서 이름을 붙여준다고 한다.
X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")
print(X)
print(Y)
# Out:
# Tensor("X_1:0", dtype=float32)
# Tensor("Y_1:0", dtype=float32)

# %%
# X 와 Y 의 상관 관계를 분석하기 위한 Hypothesis
hypothesis = W * X + b

# %%
# Cost Function
# mean(h - Y)^2 : 예측값과 실제값의 거리를 비용 함수로 정한다.
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
# Gradient Descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)

# %%
# minimize cost
train_op = optimizer.minimize(cost)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(1001):
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})
        if step % 10 == 0:
            print(step, cost_val, sess.run(W), sess.run(b))
        
    # 최적화가 완료된 모델에 테스트 값을 넣고 결과를 확인
    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 0 3.03504 [ 0.98409432] [ 0.23673326]
# 10 0.0038607 [ 0.92956948] [ 0.16010512]
# 20 0.00237308 [ 0.94478154] [ 0.12552451]
# 30 0.00145867 [ 0.95670801] [ 0.09841287]
# 40 0.000896616 [ 0.96605849] [ 0.07715695]
# 50 0.000551125 [ 0.97338939] [ 0.06049205]
# 60 0.000338765 [ 0.97913694] [ 0.04742661]
# 70 0.00020823 [ 0.98364305] [ 0.03718308]
# 80 0.000127995 [ 0.98717594] [ 0.029152]
# 90 7.86759e-05 [ 0.98994583] [ 0.02285557]
# 100 4.83609e-05 [ 0.9921174] [ 0.01791908]
# 110 2.97251e-05 [ 0.99381989] [ 0.01404877]
# 120 1.82717e-05 [ 0.99515474] [ 0.01101439]
# 130 1.1231e-05 [ 0.99620122] [ 0.00863541]
# 140 6.90329e-06 [ 0.99702173] [ 0.00677031]
# 150 4.24327e-06 [ 0.99766499] [ 0.005308]
# 160 2.60811e-06 [ 0.9981693] [ 0.00416153]
# 170 1.60346e-06 [ 0.99856472] [ 0.00326273]
# 180 9.85572e-07 [ 0.99887472] [ 0.00255803]
# 190 6.05725e-07 [ 0.99911773] [ 0.00200549]
# 200 3.72428e-07 [ 0.99930835] [ 0.00157234]
# 210 2.28917e-07 [ 0.99945772] [ 0.00123275]
# 220 1.4066e-07 [ 0.99957484] [ 0.00096648]
# 230 8.64739e-08 [ 0.99966675] [ 0.00075771]
# 240 5.31487e-08 [ 0.99973869] [ 0.00059401]
# 250 3.26873e-08 [ 0.9997952] [ 0.0004657]
# 260 2.00678e-08 [ 0.99983943] [ 0.00036508]
# 270 1.23364e-08 [ 0.99987411] [ 0.00028621]
# 280 7.58784e-09 [ 0.99990129] [ 0.00022438]
# 290 4.6649e-09 [ 0.99992257] [ 0.00017592]
# 300 2.86085e-09 [ 0.99993932] [ 0.00013797]
# 310 1.76588e-09 [ 0.99995244] [ 0.00010818]
# 320 1.0874e-09 [ 0.99996275] [  8.48458876e-05]
# 330 6.63874e-10 [ 0.99997073] [  6.64955951e-05]
# 340 4.10471e-10 [ 0.99997705] [  5.21507427e-05]
# 350 2.51613e-10 [ 0.999982] [  4.08894339e-05]
# 360 1.55964e-10 [ 0.99998587] [  3.20520521e-05]
# 370 9.44596e-11 [ 0.99998891] [  2.50902303e-05]
# 380 5.84587e-11 [ 0.99999136] [  1.96860765e-05]
# 390 3.63229e-11 [ 0.99999321] [  1.54740155e-05]
# 400 2.20931e-11 [ 0.9999947] [  1.21361554e-05]
# 410 1.36993e-11 [ 0.99999583] [  9.50560297e-06]
# 420 8.33704e-12 [ 0.99999672] [  7.45520447e-06]
# 430 5.09696e-12 [ 0.99999744] [  5.82601115e-06]
# 440 3.14534e-12 [ 0.99999797] [  4.57828719e-06]
# 450 1.91373e-12 [ 0.99999839] [  3.58487659e-06]
# 460 1.3074e-12 [ 0.99999875] [  2.79809569e-06]
# 470 7.62649e-13 [ 0.99999899] [  2.20999641e-06]
# 480 4.73695e-13 [ 0.99999923] [  1.73315925e-06]
# 490 2.46321e-13 [ 0.9999994] [  1.38347900e-06]
# 500 1.94215e-13 [ 0.99999952] [  1.09737698e-06]
# 510 9.4739e-14 [ 0.99999958] [  8.51011293e-07]
# 520 6.15804e-14 [ 0.99999964] [  7.39749396e-07]
# 530 6.15804e-14 [ 0.99999964] [  6.60276612e-07]
# 540 6.15804e-14 [ 0.9999997] [  5.96698385e-07]
# 550 6.15804e-14 [ 0.99999976] [  5.33120101e-07]
# 560 1.89478e-14 [ 0.99999982] [  3.74174306e-07]
# 570 2.36848e-14 [ 0.99999994] [  2.70859545e-07]
# 580 4.73695e-15 [ 0.99999994] [  1.75492076e-07]
# 590 4.26326e-14 [ 0.99999994] [  8.80718858e-08]
# 600 0.0 [ 1.] [  5.62827438e-08]
# 610 0.0 [ 1.] [  5.62827438e-08]
# 620 0.0 [ 1.] [  5.62827438e-08]
# 630 0.0 [ 1.] [  5.62827438e-08]
# 640 0.0 [ 1.] [  5.62827438e-08]
# 650 0.0 [ 1.] [  5.62827438e-08]
# 660 0.0 [ 1.] [  5.62827438e-08]
# 670 0.0 [ 1.] [  5.62827438e-08]
# 680 0.0 [ 1.] [  5.62827438e-08]
# 690 0.0 [ 1.] [  5.62827438e-08]
# 700 0.0 [ 1.] [  5.62827438e-08]
# 710 0.0 [ 1.] [  5.62827438e-08]
# 720 0.0 [ 1.] [  5.62827438e-08]
# 730 0.0 [ 1.] [  5.62827438e-08]
# 740 0.0 [ 1.] [  5.62827438e-08]
# 750 0.0 [ 1.] [  5.62827438e-08]
# 760 0.0 [ 1.] [  5.62827438e-08]
# 770 0.0 [ 1.] [  5.62827438e-08]
# 780 0.0 [ 1.] [  5.62827438e-08]
# 790 0.0 [ 1.] [  5.62827438e-08]
# 800 0.0 [ 1.] [  5.62827438e-08]
# 810 0.0 [ 1.] [  5.62827438e-08]
# 820 0.0 [ 1.] [  5.62827438e-08]
# 830 0.0 [ 1.] [  5.62827438e-08]
# 840 0.0 [ 1.] [  5.62827438e-08]
# 850 0.0 [ 1.] [  5.62827438e-08]
# 860 0.0 [ 1.] [  5.62827438e-08]
# 870 0.0 [ 1.] [  5.62827438e-08]
# 880 0.0 [ 1.] [  5.62827438e-08]
# 890 0.0 [ 1.] [  5.62827438e-08]
# 900 0.0 [ 1.] [  5.62827438e-08]
# 910 0.0 [ 1.] [  5.62827438e-08]
# 920 0.0 [ 1.] [  5.62827438e-08]
# 930 0.0 [ 1.] [  5.62827438e-08]
# 940 0.0 [ 1.] [  5.62827438e-08]
# 950 0.0 [ 1.] [  5.62827438e-08]
# 960 0.0 [ 1.] [  5.62827438e-08]
# 970 0.0 [ 1.] [  5.62827438e-08]
# 980 0.0 [ 1.] [  5.62827438e-08]
# 990 0.0 [ 1.] [  5.62827438e-08]
# 1000 0.0 [ 1.] [  5.62827438e-08]
#
# === Test ===
# X: 5, Y: [ 5.]
# X: 2.5, Y: [ 2.5]
